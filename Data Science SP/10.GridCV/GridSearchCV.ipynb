# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A007-E621
#
#  Directory of C:\Users\tswar\Desktop\DATA SETS
#
# 08/06/2022  09:46 PM    <DIR>          .
# 08/06/2022  09:46 PM    <DIR>          ..
# 08/06/2022  09:44 PM    <DIR>          .ipynb_checkpoints
# 05/07/2022  10:28 PM             4,213 Advertising.csv
# 05/07/2022  10:25 PM            16,161 Bahaman.xlsx
# 09/29/2019  08:41 AM           938,020 Bengaluru_House_Data.csv
# 05/07/2022  10:25 PM             9,048 Bolt diameter.xlsx
# 05/07/2022  10:26 PM            35,203 boston.csv
# 05/07/2022  10:29 PM           684,858 Churn_Modelling (1).csv
# 05/07/2022  10:26 PM            29,822 claimants.csv
# 05/07/2022  10:25 PM            10,738 Contract Renewal.xlsx
# 09/20/2019  12:04 AM       150,828,752 creditcard.csv
# 07/20/2022  11:18 AM         9,224,265 Crop-wise_State-wise_Land holdings_Area_Number.xlsx
# 06/30/2022  03:01 PM            26,801 Data Transformation.ipynb
# 08/04/2022  09:49 AM         5,057,493 data.csv
# 04/19/2022  05:39 PM            23,873 diabetes.csv
# 05/07/2022  10:29 PM         2,029,440 energy.xlsx
# 05/07/2022  10:25 PM             8,713 Fabric data.xlsx
# 07/28/2022  08:59 AM         7,834,511 Fuel Consumption EDA.ipynb
# 05/07/2022  10:28 PM            33,036 gene_expression.csv
# 05/07/2022  10:28 PM           102,993 hearing_test.csv
# 10/24/2019  02:52 AM        41,399,186 Hindi_English_Truncated_Corpus.csv
# 05/07/2022  10:27 PM               297 homeprices (1).csv
# 05/07/2022  10:27 PM               297 homeprices.csv
# 05/07/2022  10:24 PM               809 Indian Liver Patient Dataset -Description.txt
# 05/07/2022  10:24 PM            23,814 Indian Liver Patient.csv
# 05/07/2022  10:25 PM            20,450 JohnyTalkers.xlsx
# 07/21/2022  03:12 PM           978,285 KingTran.csv
# 05/07/2022  10:29 PM             4,286 Mall_Customers.csv
# 05/14/2022  08:16 PM           132,037 Matplotlib.ipynb
# 05/20/2022  01:04 PM           930,983 mini -py.pdf
# 05/07/2022  10:28 PM            15,698 mouse_viral_study.csv
# 05/07/2022  10:28 PM           374,003 mushrooms.csv
# 04/06/2022  02:41 PM            73,008 MY2022 Fuel Consumption Ratings.csv
# 07/20/2022  11:24 AM         1,434,704 nigeria_houses_data.csv
# 05/07/2022  10:28 PM            13,519 penguins_size.csv
# 02/24/2022  10:55 AM        41,399,186 Project2(Hindi_English_Corpus).csv
# 05/07/2022  10:25 PM            13,309 Promotion.xlsx
# 08/05/2022  02:19 PM         2,315,464 Regression Overfitting.pdf
# 08/04/2022  11:38 AM            38,472 sentiment analysis.ipynb
# 06/15/2022  02:33 PM           643,041 simple-linear-regression.pdf
# 05/21/2020  07:27 AM           608,346 SOCR-HeightWeight.csv
# 05/07/2022  10:27 PM         2,635,787 stroke prediction.csv
# 05/07/2022  10:26 PM             8,008 tips.csv
# 05/07/2022  10:27 PM            61,194 titanic.csv
# 11/07/2021  01:07 PM            60,302 train.csv
# 05/23/2022  07:46 PM           146,868 Untitled.ipynb
# 07/27/2022  04:15 PM            10,806 Untitled1.ipynb
# 07/28/2022  10:06 PM        21,720,880 Untitled2.ipynb
# 08/06/2022  09:46 PM             1,187 Untitled3.ipynb
# 05/07/2022  10:27 PM            11,462 Wine.csv
#               48 File(s)    291,973,628 bytes
#                3 Dir(s)  96,534,040,576 bytes free

# %%
df = pd.read_csv("MY2022 Fuel Consumption Ratings.csv")
df.head(3)
# Out:
#    Model Year   Make       Model Vehicle Class  Engine Size(L)  Cylinders  \
# 0        2022  Acura         ILX       Compact             2.4          4
# 1        2022  Acura  MDX SH-AWD    SUV: Small             3.5          6
# 2        2022  Acura  RDX SH-AWD    SUV: Small             2.0          4
#
#   Transmission Fuel Type  Fuel Consumption (City (L/100 km)  \
# 0          AM8         Z                                9.9
# 1         AS10         Z                               12.6
# 2         AS10         Z                               11.0
#
#    Fuel Consumption(Hwy (L/100 km))  Fuel Consumption(Comb (L/100 km))  \
# 0                               7.0                                8.6
# 1                               9.4                               11.2
# 2                               8.6                                9.9
#
#    Fuel Consumption(Comb (mpg))  CO2 Emissions(g/km)  CO2 Rating  Smog Rating
# 0                            33                  200           6            3
# 1                            25                  263           4            5
# 2                            29                  232           5            6

# %%
df.columns
# Out:
# Index(['Model Year', 'Make', 'Model', 'Vehicle Class', 'Engine Size(L)',
#        'Cylinders', 'Transmission', 'Fuel Type',
#        'Fuel Consumption (City (L/100 km)', 'Fuel Consumption(Hwy (L/100 km))',
#        'Fuel Consumption(Comb (L/100 km))', 'Fuel Consumption(Comb (mpg))',
#        'CO2 Emissions(g/km)', 'CO2 Rating', 'Smog Rating'],
#       dtype='object')

# %%
df.rename(columns={'Model Year':"Model_Year",'Engine Size(L)':'Engine_Size','Fuel Type':'Fuel_Type',
                  'CO2 Emissions(g/km)':'Co2','CO2 Rating':'Co2_Rating','Smog Rating':'Smoke_Rating'},inplace=True)

# %%
df.columns
# Out:
# Index(['Model_Year', 'Make', 'Model', 'Vehicle Class', 'Engine_Size',
#        'Cylinders', 'Transmission', 'Fuel_Type',
#        'Fuel Consumption (City (L/100 km)', 'Fuel Consumption(Hwy (L/100 km))',
#        'Fuel Consumption(Comb (L/100 km))', 'Fuel Consumption(Comb (mpg))',
#        'Co2', 'Co2_Rating', 'Smoke_Rating'],
#       dtype='object')

# %%
df.drop(columns=['Fuel Consumption (City (L/100 km)','Fuel Consumption(Hwy (L/100 km))','Fuel Consumption(Comb (mpg))'],inplace=True)

# %%
df.rename(columns={'Fuel Consumption(Comb (L/100 km))':"Consumption"},inplace=True)

# %%
df.columns
# Out:
# Index(['Model_Year', 'Make', 'Model', 'Vehicle Class', 'Engine_Size',
#        'Cylinders', 'Transmission', 'Fuel_Type', 'Consumption', 'Co2',
#        'Co2_Rating', 'Smoke_Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model_Year     946 non-null    int64
#  1   Make           946 non-null    object
#  2   Model          946 non-null    object
#  3   Vehicle Class  946 non-null    object
#  4   Engine_Size    946 non-null    float64
#  5   Cylinders      946 non-null    int64
#  6   Transmission   946 non-null    object
#  7   Fuel_Type      946 non-null    object
#  8   Consumption    946 non-null    float64
#  9   Co2            946 non-null    int64
#  10  Co2_Rating     946 non-null    int64
#  11  Smoke_Rating   946 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 88.8+ KB

# %%
df.head(1)
# Out:
#    Model_Year   Make Model Vehicle Class  Engine_Size  Cylinders Transmission  \
# 0        2022  Acura   ILX       Compact          2.4          4          AM8
#
#   Fuel_Type  Consumption  Co2  Co2_Rating  Smoke_Rating
# 0         Z          8.6  200           6             3

# %%
df.isnull().sum()
# Out:
# Model_Year       0
# Make             0
# Model            0
# Vehicle Class    0
# Engine_Size      0
# Cylinders        0
# Transmission     0
# Fuel_Type        0
# Consumption      0
# Co2              0
# Co2_Rating       0
# Smoke_Rating     0
# dtype: int64

# %%
cate =[]
for i in df.columns:
    try:
        sns.boxplot(df[i])
        plt.show()
    except:
        cate.append(i)
        pass

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.drop(columns=["Smoke_Rating","Model_Year"],inplace=True)

# %%
df.dtypes
# Out:
# Make              object
# Model             object
# Vehicle Class     object
# Engine_Size      float64
# Cylinders          int64
# Transmission      object
# Fuel_Type         object
# Consumption      float64
# Co2                int64
# Co2_Rating         int64
# dtype: object

# %%
for i in cate:
    x = df[i].nunique()
    print("{} contain No of :: {} :: Values".format(i,x))
# Out:
# Make contain No of :: 39 :: Values
# Model contain No of :: 715 :: Values
# Vehicle Class contain No of :: 14 :: Values
# Transmission contain No of :: 23 :: Values
# Fuel_Type contain No of :: 4 :: Values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for i in cate:
    df[i]=le.fit_transform(df[[i]])

# %%
df.head(3)
# Out:
#    Make  Model  Vehicle Class  Engine_Size  Cylinders  Transmission  \
# 0     0    349              0          2.4          4             7
# 1     0    410              7          3.5          6             8
# 2     0    513              7          2.0          4             8
#
#    Fuel_Type  Consumption  Co2  Co2_Rating
# 0          3          8.6  200           6
# 1          3         11.2  263           4
# 2          3          9.9  232           5

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine_Size', 'Cylinders',
#        'Transmission', 'Fuel_Type', 'Consumption', 'Co2', 'Co2_Rating'],
#       dtype='object')

# %%
x=df.drop('Consumption',axis=1)
x
# Out:
#      Make  Model  Vehicle Class  Engine_Size  Cylinders  Transmission  \
# 0       0    349              0          2.4          4             7
# 1       0    410              7          3.5          6             8
# 2       0    513              7          2.0          4             8
# 3       0    514              7          2.0          4             8
# 4       0    615              0          2.0          4             8
# ..    ...    ...            ...          ...        ...           ...
# 941    38    695              7          2.0          4            12
# 942    38    696              7          2.0          4            12
# 943    38    697              7          2.0          4            12
# 944    38    698              8          2.0          4            12
# 945    38    699              8          2.0          4            12
#
#      Fuel_Type  Co2  Co2_Rating
# 0            3  200           6
# 1            3  263           4
# 2            3  232           5
# 3            3  242           5
# 4            3  230           5
# ..         ...  ...         ...
# 941          3  219           5
# 942          3  219           5
# 943          3  232           5
# 944          3  236           5
# 945          3  252           5
#
# [946 rows x 9 columns]

# %%
y=df['Consumption']
y
# Out:
# 0       8.6
# 1      11.2
# 2       9.9
# 3      10.3
# 4       9.8
#        ...
# 941     9.4
# 942     9.4
# 943     9.9
# 944    10.1
# 945    10.8
# Name: Consumption, Length: 946, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=33)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = RandomForestRegressor()

# %%
param_grid={
        "n_estimators":[100,500],
        "max_features":['auto','sqrt','log2'],
        "max_depth":[4,5,6,7,8],
         "criterion":['squared_error']   
}

# %%
c_ran = GridSearchCV(estimator=model,
    param_grid=param_grid,cv=5)

# %%
c_ran.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 500]})

# %%
c_ran.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'n_estimators': 500}

# %%
model1 = RandomForestRegressor(n_estimators=500,max_features='log2',max_depth=8,criterion='squared_error')

# %%
model1.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=8, max_features='log2', n_estimators=500)

# %%
pred =model1.predict(x_test)

# %%
pred
# Out:
# array([14.70271222, 10.80516667, 16.19348202, 13.49374842,  7.92946265,
#        10.77773312,  9.58714563, 12.18935412, 13.77005742,  7.93652944,
#        10.19595631, 10.97091567, 13.60304886, 10.38135666,  9.83228778,
#         9.42331558, 10.53077735,  9.89552193,  9.19783784, 13.60304886,
#        13.90400225, 10.24527807, 10.96291831,  9.57239011,  6.78896383,
#        12.09917678,  7.86798941, 10.50999855, 13.47160691, 14.76478126,
#        14.80075704,  7.33337218, 14.54049118,  8.72712973,  7.3859675 ,
#        14.04743934, 10.4561076 ,  7.55811557,  4.8333638 , 11.11709505,
#        15.67555897,  7.89771488, 13.29190619,  7.04204808,  9.93919852,
#         9.06188143, 11.02689827,  9.12258747,  8.33572355,  9.20261896,
#        15.69127005, 10.56669696, 13.70349197, 11.81580577,  7.59272688,
#        13.94022938, 13.95986807, 10.11335305,  7.86879463, 14.73976695,
#        12.26373423, 11.72357235, 11.31413851, 11.66928123,  8.25575363,
#        14.65534918,  9.47308841, 11.419354  ,  7.32207588, 10.75642971,
#        13.81163798,  7.57467243,  9.42094017,  8.60067   , 10.019332  ,
#        13.70831402, 10.03907388,  9.41665235, 14.83170431,  6.86102786,
#        16.11981496,  9.33592611, 11.95819711, 10.57728463, 11.77668496,
#        13.19661832, 11.83472415,  9.23720942,  8.4196469 ,  8.38142009,
#        11.21736548,  9.52896316, 14.62243057, 10.34586006,  7.91080264,
#        20.55035132, 13.41320543, 11.27267581,  9.33658204,  9.61522255,
#        11.24278321,  8.01699649, 12.20793357,  8.55226523,  9.47545908,
#        13.61761319, 12.69751654, 12.21131652, 10.5442569 ,  8.77651349,
#         8.78828872, 14.2153495 ,  9.83389052, 13.41364525, 12.43041992,
#         9.27495027, 11.28923667,  9.7379691 , 13.97211976,  6.92926196,
#        12.2113331 , 14.01713301,  7.12244902, 13.76929425,  9.83656857,
#         9.46534099, 11.66800815, 12.19153468, 10.13627335, 12.22028482,
#        14.91801695,  6.17049141,  9.93777496,  8.7785184 , 13.6190873 ,
#         6.91197432, 11.60653125, 15.69288255,  8.10767249,  6.18587086,
#        15.73835695,  9.62762528, 11.51400216, 13.70582524, 13.77005742,
#        12.31675377, 11.65140091, 11.68052045, 11.7389314 , 14.04257745,
#        10.32541851, 13.30583071,  9.34593299, 14.14476797,  8.56945795,
#        10.33756155, 11.30261908,  9.37434774, 10.41667743, 10.26628971,
#        14.13402939, 13.382347  , 13.79296757, 10.32031473, 10.67160222,
#         8.72195546, 15.81431428,  6.03256021, 11.36925831,  8.14647137,
#         7.11782654,  7.01746568,  7.62205968, 11.86312808, 12.22254854,
#        14.12095399,  8.32529376,  4.96323047, 13.79448843, 13.74863694,
#         4.74249815,  7.08383506, 14.91490489, 13.34906145,  7.50480331,
#        12.18222751,  7.21189938, 11.22360678, 10.29771649, 11.26672576,
#         9.45498125, 15.69888255, 13.2528958 ,  7.17774728,  6.29536593,
#         9.45135479, 10.45371817, 10.509711  , 14.73507338, 14.11438296,
#         6.82649211, 14.00830106, 10.20161219,  8.21094205, 11.72526569,
#        11.71054779,  9.27907563,  9.39929837, 11.9002711 , 17.8210294 ,
#         9.92267667, 14.84434823, 11.31809568,  9.77687509,  9.68701941,
#         8.44781765,  8.63663773, 11.24939854, 11.80267163,  9.83076971,
#         8.28967413,  9.95247148, 12.45914944,  8.22305584,  8.4880304 ,
#        12.47822022,  9.45914358, 11.40961791, 10.02421225, 10.24282508,
#         9.64228908, 11.10735868, 15.71887569, 10.78827397, 11.61314581,
#        12.47206792, 11.79325828,  7.89290475,  7.09610211, 12.20625026,
#        14.13726683,  7.41849686, 13.33469862, 17.82108136, 12.64371236,
#        13.87957858, 10.47334683, 11.55424195,  9.85133008, 13.70241265,
#         9.45287558,  9.40128672, 10.8075769 , 11.91485722, 11.46995916,
#        10.44693818, 20.57435132, 14.92719593, 10.45379006, 15.80896428,
#         8.01116426,  8.27395848,  5.67137875, 15.93808824, 16.04720349,
#         7.17724864, 11.76186584, 10.80941374,  9.53583451,  9.28506102,
#         8.30790471,  9.90936216,  9.48753514, 11.71169093, 11.43876264,
#         9.40360608, 12.36831408, 12.16766848, 11.67991403, 14.11049175,
#         7.51069529, 14.76900936,  8.1197386 , 11.83042509])

# %%
model1.score(x_train,y_train)
# Out:
# 0.9949531164720459

# %%
model1.score(x_test,y_test)
# Out:
# 0.9852420742296942

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(pred,y_test)
# Out:
# 0.11286261146080959

# %%
import math

# %%
math.sqrt(mean_squared_error(pred,y_test))
# Out:
# 0.3359503109997215
